# %%
config = {
  "raw_documents" : "/FileStore/tables/cfuentes/input_test",
  "english_documents": "/FileStore/tables/cfuentes/english_articles.parquet",
  "tagcloud_parquet" : "/FileStore/tables/cfuentes/tag_cloud.parquet",
  "es_nodes" : "51.104.144.96",
  "es_port" : "9200",
  "es_user" : "elastic",
  "es_pass" : "h5UfRM71MMD2y3AZrB1243V2",
  "es_index" : "index/cfuentes_covid_docs",
  "indegree_parquet" : "/FileStore/tables/cfuentes/indegrees.parquet",
  "origin_path" : "/FileStore/tables/cfuentes/input_test/{}.json",
  "error_destination_path" : "/FileStore/tables/cfuentes/error/{}.json",
  "processed_destination_path" : "/FileStore/tables/cfuentes/processed/{}.json"
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.notebook.run("FilterNonEnglishDocuments", 600, config)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: &#39;Ok&#39;</div>

# %%
dbutils.notebook.run("ElasticSearchIndexing", 600, config)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: &#39;Ok&#39;</div>

# %%
dbutils.notebook.run("GraphAnalysis", 600, config)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: &#39;Ok&#39;</div>

# %%
dbutils.notebook.run("ProcessCheck", 600, config)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: &#39;Ok&#39;</div>
